# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.table import Table
from astropy import units as u
plt.ion()
import os
# %matplotlib widget

# %% [markdown]
# ### Test interactive plot

# %%
#plt.plot([1,2,3], [1,2,3])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# $$E = mc^2$$

# %% [markdown]
# $$F = ma$$

# %% [markdown]
# $$pv = nRT$$

# %%
s = "Spam egg spam spam"
print (s)
# Out:
# Spam egg spam spam

# %%
s = [1,4,5,8]

# %%
r = 4 + s[2]
print (r)
# Out:
# 9

# %%
e = "Yoanna" + " Nikolova"
print (e)
# Out:
# Yoanna Nikolova

# %%
e += "!"

# %%
print(e)
# Out:
# Yoanna Nikolova!

# %%
f = e.upper()
print(f)
# Out:
# YOANNA NIKOLOVA!

# %%
n1 = f.split(" ")[0]
n2 = f.split(" ")[1].split("!")[0]
print(n1)
print(n2)
# Out:
# YOANNA
# NIKOLOVA

# %%
l1 = [4, 5.5, 22, "damn"]

# %%
l1[0]
# Out:
# 4

# %%
l1[3][2]
# Out:
# 'm'

# %%
l1[1]= 15
print(l1)
# Out:
# [4, 15, 22, 'damn']

# %%
l1.append("school")
print(l1)
# Out:
# [4, 15, 22, 'damn', 'school']

# %%
l1.insert(1, 7)
print(l1)
# Out:
# [4, 7, 15, 22, 'damn', 'school']

# %%
l1.pop(1)
print(l1)
# Out:
# [4, 15, 22, 'damn', 'school']

# %%
len(l1)
# Out:
# 5

# %%
l1[-1]
# Out:
# 'school'

# %%
l1[-2]
# Out:
# 'damn'

# %%
l1.append("hello")

# %%
l1.append(3)

# %%
print(l1)
# Out:
# [4, 15, 22, 'damn', 'school', 'hello', 3]

# %%
g = 3.4
k = int(g)
print (type(k))
print (type(g))
print (type(l1[1]))
w = int(float('5.5')) + int(float('4.3'))
print(w)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>
# 9

# %%
print ("The result is " + str(w))
# Out:
# The result is 9
